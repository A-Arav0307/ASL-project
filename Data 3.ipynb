# %%
import Accuracy

# %%
Accuracy.acc_det("Data 3 Accuracy.csv","Data 3 Accuracy.png")
# Out:
# testing
# {'train_accuracy': {'slope': np.float64(-0.014966920569609361),
#   'intercept': np.float64(1.3352778042773916),
#   'r2_score': 0.3778351634768118,
#   'rmse': 0.11074645236398489,
#   'predicted_limit': np.float64(0.7489078278667015)},
#  'val_accuracy': {'slope': np.float64(-0.006396279503369551),
#   'intercept': np.float64(1.2193717238361126),
#   'r2_score': 0.634652410836881,
#   'rmse': 0.027983911193014643,
#   'predicted_limit': np.float64(0.820094463773545)},
#  'train_loss': {'slope': np.float64(-0.061806391111735186),
#   'intercept': np.float64(-0.0940109710916206),
#   'r2_score': 0.7477970098910386,
#   'rmse': 0.20697241354778814,
#   'decay_rate': np.float64(0.061806391111735186)},
#  'val_loss': {'slope': np.float64(-0.04382083523222079),
#   'intercept': np.float64(-0.2772721197605227),
#   'r2_score': 0.7839631685495942,
#   'rmse': 0.13264550746746764,
#   'decay_rate': np.float64(0.04382083523222079)}}
