# %%
import Accuracy

# %%
Accuracy.acc_det("Data 3 Accuracy.csv","Data 2 Accuracy.png")
# Out:
# testing
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Accuracy.acc_det("Data 3 Accuracy.csv","Data 2 Accuracy.png")
#
# File c:\Users\oneal\OneDrive\Desktop\Stats\ASL-project\Accuracy.py:71, in acc_det(data, name)
#      64 plt.grid(True)
#      66 # Store accuracy regression stats
#      67 regression_stats['train_accuracy'] = {
#      68     'slope': model_train_acc.coef_[0][0],
#      69     'intercept': model_train_acc.intercept_[0],
#      70     'r2_score': r2_score(train_acc, train_acc_pred),
# ---> 71     'rmse': root_mean_squared_error(train_acc, train_acc_pred, squared=False)
#      72 }
#      74 regression_stats['val_accuracy'] = {
#      75     'slope': model_val_acc.coef_[0][0],
#      76     'intercept': model_val_acc.intercept_[0],
#      77     'r2_score': r2_score(val_acc, val_acc_pred),
# ...
