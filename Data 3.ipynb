# %%
import Accuracy2

# %%
Accuracy2.acc_det("Data 3 Accuracy.csv","Data 3 Accuracy.png")
# Out:
# testing
# {'train_accuracy': {'slope': np.float64(-0.05094918665194149),
#   'intercept': np.float64(-1.493093857344757),
#   'r2_score': 0.6923890732535763,
#   'rmse': 0.1958208162194866,
#   'decay_rate': np.float64(0.05094918665194149),
#   'predicted_limit': 1.0},
#  'val_accuracy': {'slope': np.float64(-0.032086132949411254),
#   'intercept': np.float64(-1.7214372890587786),
#   'r2_score': 0.7799127824920199,
#   'rmse': 0.09828507971327378,
#   'decay_rate': np.float64(0.032086132949411254),
#   'predicted_limit': 1.0},
#  'train_loss': {'slope': np.float64(-0.061806391111735186),
#   'intercept': np.float64(-0.0940109710916206),
#   'r2_score': 0.7477970098910386,
#   'rmse': 0.20697241354778814,
#   'decay_rate': np.float64(0.061806391111735186)},
#  'val_loss': {'slope': np.float64(-0.04382083523222079),
#   'intercept': np.float64(-0.2772721197605227),
#   'r2_score': 0.7839631685495942,
#   'rmse': 0.13264550746746764,
#   'decay_rate': np.float64(0.04382083523222079)}}
