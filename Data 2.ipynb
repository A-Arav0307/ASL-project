# %%
import Accuracy2

# %%
Accuracy2.acc_det("Data 2 Accuracy Cut.csv","Data 2 Accuracy.png")
# Out:
# testing
# {'train_accuracy': {'slope': np.float64(-0.4786610794111072),
#   'intercept': np.float64(-1.2597400223768775),
#   'r2_score': 0.8579565158368309,
#   'rmse': 0.5594137153526471,
#   'decay_rate': np.float64(0.4786610794111072),
#   'predicted_limit': 1.0},
#  'val_accuracy': {'slope': np.float64(-0.6648469037803545),
#   'intercept': np.float64(-1.374330994123231),
#   'r2_score': 0.8304534607066408,
#   'rmse': 0.8628502713389374,
#   'decay_rate': np.float64(0.6648469037803545),
#   'predicted_limit': 1.0},
#  'train_loss': {'slope': np.float64(-0.2795373548856866),
#   'intercept': np.float64(1.3839099516147928),
#   'r2_score': 0.7417097877784349,
#   'rmse': 0.47380953375967483,
#   'decay_rate': np.float64(0.2795373548856866)},
#  'val_loss': {'slope': np.float64(-0.2383277476170557),
#   'intercept': np.float64(0.9136934702156406),
#   'r2_score': 0.716756516277756,
#   'rmse': 0.43032415193667956,
#   'decay_rate': np.float64(0.2383277476170557)}}
