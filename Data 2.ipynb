# %%
import Accuracy

# %%
Accuracy.acc_det("Data 2 Accuracy Cut.csv","Data 2 Accuracy.png")
# Out:
# testing
# {'train_accuracy': {'slope': np.float64(-0.08204830700687915),
#   'intercept': np.float64(1.6147267466882531),
#   'r2_score': 0.3324149978319031,
#   'rmse': 0.33397163226875193,
#   'predicted_limit': np.float64(0.6192998301731016)},
#  'val_accuracy': {'slope': np.float64(-0.054424328060005606),
#   'intercept': np.float64(1.4052523714304557),
#   'r2_score': 0.3163935466886063,
#   'rmse': 0.2297784622033813,
#   'predicted_limit': np.float64(0.7116159490854052)},
#  'train_loss': {'slope': np.float64(-0.2795373548856866),
#   'intercept': np.float64(1.3839099516147928),
#   'r2_score': 0.7417097877784349,
#   'rmse': 0.47380953375967483,
#   'decay_rate': np.float64(0.2795373548856866)},
#  'val_loss': {'slope': np.float64(-0.2383277476170557),
#   'intercept': np.float64(0.9136934702156406),
#   'r2_score': 0.716756516277756,
#   'rmse': 0.43032415193667956,
#   'decay_rate': np.float64(0.2383277476170557)}}
